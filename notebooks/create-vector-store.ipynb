# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

from src.prepare_data import prepare_data

# %%
vs = prepare_data(
    data_path='../data/preprocess/dataset.txt',
    chunking_config='../config/chunking.yaml', 
    embedding_config='../config/embedding.yaml', 
    save_path='../config/collection'
)
# Out:
# No sentence-transformers model found with name HooshvareLab/bert-fa-base-uncased. Creating a new one with mean pooling.
