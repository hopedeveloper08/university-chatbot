# %% [markdown]
# # Initial

# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

from src.rag_system import get_prompt_template
from src.rag_system import get_llm

# %% [markdown]
# # Prompt template

# %%
prompt_template = get_prompt_template('../config/prompt_template.txt')

# %% [markdown]
# # LLM

# %%
llm = get_llm('../config/generator.yaml')

# %% [markdown]
# # Chain

# %%
model = prompt_template | llm

# %%
result = model.invoke({
    'input': 'خودت را معرفی کن',
    'context': 'مشروطی فقط 3 بار ممکن است.'
})

# %%
print(result.content)
# Out:
# با سلام و احترام،
#
# خودت را معرفی کن؟
#
# بر اساس اطلاعات موجود در آیین‌نامه‌ها و مقررات دانشگاه، من دستیار هوشمند دانشگاه ولی عصر رفسنجان هستم. هدف من پاسخگویی به سوالات دانشجویان و کارکنان با استفاده از پایگاه دانش دانشگاه و ارائه اطلاعات دقیق و به‌روز در راستای تسهیل دسترسی به اطلاعات مورد نیاز است.
#
# در صورتی که سوالی دارید، با کمال میل به شما پاسخ می‌دهم.
